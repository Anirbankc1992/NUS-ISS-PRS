# %% [markdown]
# ## **1. Mount google drive**
# ---

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## **2. Import the necessary libraries**
# ---

# %%
import h5py
import matplotlib
import sklearn
import numpy as np
import pandas as pd
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.callbacks import ModelCheckpoint,CSVLogger
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model


print("Versions of key libraries")
print("---")
print("tensorflow: ", tf.__version__)
print("numpy:      ", np.__version__)
print("matplotlib: ", matplotlib.__version__)
print("sklearn:    ", sklearn.__version__)
# Out:
# Versions of key libraries
# ---
# tensorflow:  2.3.0
# numpy:       1.18.5
# matplotlib:  3.2.2
# sklearn:     0.22.2.post1

# %% [markdown]
# ## **3. Set matplotlib to have seaborn plot style**
# ---

# %%
plt.style.use('seaborn')                   # if want to use the default style, set 'classic'
plt.rcParams['ytick.right']     = True
plt.rcParams['ytick.labelright']= True
plt.rcParams['ytick.left']      = False
plt.rcParams['ytick.labelleft'] = False
plt.rcParams['figure.figsize']  = [7,7]   # Set the figure size to be 7 inch for (width,height)

print("Matplotlib setup completes.")
# Out:
# Matplotlib setup completes.

# %% [markdown]
# ## **4. Load ECG data**
# ---
# * Step 1: Load the h5py file and extract the values
# * Step 2: Convert the data and label into numpy arrays
# * Step 3: Tranpose the data and label
# * Step 4: Make separate arrays for Normal and CAD ECG signals
# * Step 5: Inspect the shape and data type of the 'nor' and 'cad' arrays

# %%
f        = h5py.File('/content/gdrive/My Drive/iss/prmls/data/cad5sec.mat','r')# Step 1
X        = f["data"]
Y        = f["classLabel"]

                                                                                # Step 2
data     = np.array(X)                                                          
label    = np.array(Y)

                                                                                # Step 3
data     = np.transpose(data)                                                   
label    = np.transpose(label)

                                                                                # Step 4
nor      = data[0:32000]
cad      = data[32000:38120]

                                                                                # Step 5
print('The shape of nor is', nor.shape, 'and the data type is', nor.dtype)
print('The shape of cad is', cad.shape, 'and the data type is', cad.dtype)
# Out:
# The shape of nor is (32000, 1285) and the data type is float64
# The shape of cad is (6120, 1285) and the data type is float64

# %% [markdown]
# ## **6. Create makeSteps function**
# ---

# %%
def makeSteps(dat, length, dist):
    width           = dat.shape[1]
    numOfSteps      = int(np.floor((width-length)/dist)+1)
    
                                        # Initialize the output
    segments        = np.zeros([dat.shape[0],numOfSteps,length],
                               dtype=dat.dtype)
    
    for l in range(numOfSteps):
        segments[:,l,:]     = dat[:,(l*dist):(l*dist+length)]
        
    return segments

print(makeSteps)
# Out:
# <function makeSteps at 0x7f32041dcea0>

# %% [markdown]
# ## **7. Prepare data for training and testing**
# ---
# * Step 1: Split the dataset into training and testing
# * Step 2: Generate segments for each signal
# * Step 3: Consolidate the arrays
# * Step 4: Inspect the data shape and type

# %%
                                                                                # Step 1
trNor        = nor[0:28800].copy()
tsNor        = nor[28800:32000].copy()
trCad        = cad[0:5000].copy()
tsCad        = cad[5000:6120].copy()

                                                                                # Step 2
length       = 36
dist         = 24
trNorS       = makeSteps(trNor, length, dist)
tsNorS       = makeSteps(tsNor, length, dist)
trCadS       = makeSteps(trCad, length, dist)
tsCadS       = makeSteps(tsCad, length, dist)

                                                                                # Step 3
trDat        = np.vstack([trNorS,trCadS])
tsDat        = np.vstack([tsNorS,tsCadS])

trLbl        = np.vstack([np.zeros([trNorS.shape[0],1]),
                          np.ones([trCadS.shape[0],1])])
tsLbl        = np.vstack([np.zeros([tsNorS.shape[0],1]),
                          np.ones([tsCadS.shape[0],1])])

                                                                                # Step 4
print('The shape of trDat is', trDat.shape, "and the type is", trDat.dtype)
print('The shape of trLbl is', trLbl.shape, "and the type is", trLbl.dtype)
print('')
print('The shape of tsDat is', tsDat.shape, "and the type is", tsDat.dtype)
print('The shape of tsLbl is', tsLbl.shape, "and the type is", tsLbl.dtype)
# Out:
# The shape of trDat is (33800, 53, 36) and the type is float64
# The shape of trLbl is (33800, 1) and the type is float64
#
# The shape of tsDat is (4320, 53, 36) and the type is float64
# The shape of tsLbl is (4320, 1) and the type is float64

# %% [markdown]
# ## **8. Define the LSTM model (to be completed)**
# ___
# * Step 1: Set a name for the coming model (required for saving)
# * Step 2: Define the LSTM model (to be completed)
# * Step 3: Create models for training and testing
# * Step 4: Display the summary of the model of interest

# %%
modelname   = 'wks3_2_1'                                                        # Step 1

                                                                                # Step 2
def createModel():        
  inputs= Input(shape=(trDat.shape[1],length))
  y = LSTM(32,
  return_sequences=True,
  dropout=0.25,
  recurrent_dropout=0.25)(inputs)
  y = LSTM(32,
  return_sequences=True,
  dropout=0.5,
  recurrent_dropout=0.25)(y)
  y = LSTM(32,
  return_sequences=True,
  dropout=0.25)(y)
  y = LSTM(64, dropout=0.25)(y)
  y = Dense(1, activation='sigmoid')(y)

  model = Model(inputs=inputs,outputs=y)
  model.compile(loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy'])

  return model

                                                                                # Step 3
model       = createModel() # This is meant for training
modelGo     = createModel() # This is used for final testing

model.summary()                                                                 # Step 4
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 53, 36)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 53, 32)            8832
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 53, 32)            8320
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 53, 32)            8320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 50,369
# Trainable params: 50,369
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **9. Create the callbacks to be applied during training**
# ---
# * Step 1: Create a callback to save the model from an epoch when validation accuracy is the highest
# * Step 2: Create a callback to save the training loss, training accuracy, validation loss and validation accuracy of each epoch into a csv file
# * Step 3: Put the two callback objects into a list

# %%
                                                                                # Step 1
folderpath      = '/content/gdrive/My Drive/iss/prmls/colab/'
filepath        = folderpath + modelname + ".hdf5"
checkpoint      = ModelCheckpoint(filepath, 
                                  monitor='val_accuracy', 
                                  verbose=0, 
                                  save_best_only=True, 
                                  mode='max')

csv_logger      = CSVLogger(folderpath+modelname +'.csv')                       # Step 2
callbacks_list  = [checkpoint,csv_logger]                                       # Step 3

print("Callbacks created:")
print(callbacks_list[0])
print(callbacks_list[1])
print('')
print("Path to model:", filepath)
print("Path to log:  ", folderpath+modelname+'.csv')
# Out:
# Callbacks created:
# <tensorflow.python.keras.callbacks.ModelCheckpoint object at 0x7f31fd53deb8>
# <tensorflow.python.keras.callbacks.CSVLogger object at 0x7f31fd53def0>
#
# Path to model: /content/gdrive/My Drive/iss/prmls/colab/wks3_2_1.hdf5
# Path to log:   /content/gdrive/My Drive/iss/prmls/colab/wks3_2_1.csv

# %% [markdown]
# ## **10. Train the deep learning model**
# ___

# %%
model.fit(trDat, 
          trLbl, 
          validation_data=(tsDat, tsLbl), 
          epochs=40, 
          batch_size=128,
          shuffle=True,
          callbacks=callbacks_list)
# Out:
# Epoch 1/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.1988 - accuracy: 0.9272 - val_loss: 1.0865 - val_accuracy: 0.7600
# Epoch 2/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0876 - accuracy: 0.9723 - val_loss: 0.8717 - val_accuracy: 0.7773
# Epoch 3/40
# 265/265 [==============================] - 68s 257ms/step - loss: 0.0684 - accuracy: 0.9776 - val_loss: 0.5875 - val_accuracy: 0.8338
# Epoch 4/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0512 - accuracy: 0.9830 - val_loss: 0.3121 - val_accuracy: 0.8750
# Epoch 5/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0431 - accuracy: 0.9846 - val_loss: 0.3690 - val_accuracy: 0.8808
# Epoch 6/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0380 - accuracy: 0.9863 - val_loss: 0.3769 - val_accuracy: 0.8907
# Epoch 7/40
# 265/265 [==============================] - 66s 247ms/step - loss: 0.0305 - accuracy: 0.9883 - val_loss: 0.4643 - val_accuracy: 0.8792
# Epoch 8/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0271 - accuracy: 0.9899 - val_loss: 0.2235 - val_accuracy: 0.9229
# Epoch 9/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0231 - accuracy: 0.9915 - val_loss: 0.7440 - val_accuracy: 0.8750
# Epoch 10/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.6438 - val_accuracy: 0.8789
# Epoch 11/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.7052 - val_accuracy: 0.8803
# Epoch 12/40
# 265/265 [==============================] - 69s 259ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.9034 - val_accuracy: 0.8687
# Epoch 13/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.5335 - val_accuracy: 0.8780
# Epoch 14/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.8747 - val_accuracy: 0.8750
# Epoch 15/40
# 265/265 [==============================] - 66s 247ms/step - loss: 0.0169 - accuracy: 0.9936 - val_loss: 0.7310 - val_accuracy: 0.8785
# Epoch 16/40
# 265/265 [==============================] - 65s 247ms/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 0.5722 - val_accuracy: 0.8810
# Epoch 17/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.5073 - val_accuracy: 0.8775
# Epoch 18/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.6392 - val_accuracy: 0.8769
# Epoch 19/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.5907 - val_accuracy: 0.8778
# Epoch 20/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0107 - accuracy: 0.9960 - val_loss: 0.8450 - val_accuracy: 0.8727
# Epoch 21/40
# 265/265 [==============================] - 68s 257ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.2808 - val_accuracy: 0.9039
# Epoch 22/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.7323 - val_accuracy: 0.8792
# Epoch 23/40
# 265/265 [==============================] - 66s 250ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.9046 - val_accuracy: 0.8644
# Epoch 24/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 0.8433 - val_accuracy: 0.8609
# Epoch 25/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.5012 - val_accuracy: 0.8926
# Epoch 26/40
# 265/265 [==============================] - 65s 247ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.6899 - val_accuracy: 0.8681
# Epoch 27/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.9247 - val_accuracy: 0.8799
# Epoch 28/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.7073 - val_accuracy: 0.8840
# Epoch 29/40
# 265/265 [==============================] - 65s 247ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.6393 - val_accuracy: 0.8903
# Epoch 30/40
# 265/265 [==============================] - 65s 247ms/step - loss: 0.0067 - accuracy: 0.9974 - val_loss: 0.7355 - val_accuracy: 0.8720
# Epoch 31/40
# 265/265 [==============================] - 68s 256ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.7104 - val_accuracy: 0.8836
# Epoch 32/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0070 - accuracy: 0.9971 - val_loss: 0.4083 - val_accuracy: 0.9035
# Epoch 33/40
# 265/265 [==============================] - 65s 247ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.4755 - val_accuracy: 0.8998
# Epoch 34/40
# 265/265 [==============================] - 65s 246ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.8250 - val_accuracy: 0.8576
# Epoch 35/40
# 265/265 [==============================] - 65s 246ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.9677 - val_accuracy: 0.8743
# Epoch 36/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.7148 - val_accuracy: 0.8843
# Epoch 37/40
# 265/265 [==============================] - 66s 249ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.8451 - val_accuracy: 0.8850
# Epoch 38/40
# 265/265 [==============================] - 65s 246ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.9860 - val_accuracy: 0.8866
# Epoch 39/40
# 265/265 [==============================] - 66s 248ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.1628 - val_accuracy: 0.9377
# Epoch 40/40
# 265/265 [==============================] - 68s 256ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.7599 - val_accuracy: 0.8829

# %% [markdown]
# ## **11. Validate the deep learning model**
# ---
# * Step 1: Load the trained weights and compile the model
# * Step 2: Make prediction

# %%
                                                                                # Step 1
modelGo.load_weights(filepath)
print("Model weights loaded from:", filepath)

modelGo.compile(loss='binary_crossentropy', 
                optimizer='adam', 
                metrics=['accuracy'])

predicts    = modelGo.predict(tsDat)                                           # Step 2
print("Prediction completes.")
# Out:
# Model weights loaded from: /content/gdrive/My Drive/iss/prmls/colab/wks3_2_1.hdf5
# Prediction completes.

# %% [markdown]
# ## **12. Report classification metrics**
# ---
# * Step 1: Setup the label
# * Step 2: Calculate the accuracy score
# * Step 3: Generate classification report

# %%
                                                                                # Step 1
labelname   = ['Normal',          # The label for reporting metrics
               'CAD']
                                                                                
testScores  = metrics.accuracy_score(tsLbl,predicts.round())                    # Step 2
              
                                                                                # Step 3
print("Best accuracy (on testing dataset): %.2f%%" % (testScores*100))
print(metrics.classification_report(tsLbl,
                                    predicts.round(),
                                    target_names=labelname,
                                    digits=4))
# Out:
# Best accuracy (on testing dataset): 93.77%
#               precision    recall  f1-score   support
#
#       Normal     0.9536    0.9628    0.9582      3200
#          CAD     0.8907    0.8661    0.8782      1120
#
#     accuracy                         0.9377      4320
#    macro avg     0.9222    0.9144    0.9182      4320
# weighted avg     0.9373    0.9377    0.9374      4320

# %% [markdown]
# ## **13. Print confusion matrix**
# ---

# %%
confusion   = metrics.confusion_matrix(tsLbl,predicts.round())    
print(confusion)
# Out:
# [[3081  119]
#  [ 150  970]]

# %% [markdown]
# ## **14. Plot curves on validation loss and accuracy**
# ---

# %%
records     = pd.read_csv(folderpath+modelname +'.csv')
plt.figure()
plt.subplot(211)
plt.plot(records['val_loss'], label="validation")
plt.plot(records['loss'],label="training")
plt.yticks([0.00,0.50,1.00,1.50])
plt.title('Loss value',fontsize=12)

ax          = plt.gca()
ax.set_xticklabels([])

plt.subplot(212)
plt.plot(records['val_accuracy'],label="validation")
plt.plot(records['accuracy'],label="training")
plt.yticks([0.5,0.6,0.7,0.8])
plt.title('Accuracy',fontsize=12)
ax.legend()
plt.show()

# %% [markdown]
# ## **15. Save the model plot**
# ---

# %%
plotpath  = folderpath+modelname+'_plot.png'
plot_model(model, 
           to_file=plotpath, 
           show_shapes=True, 
           show_layer_names=False,
           rankdir='TB')

print("Path to plot:", plotpath)
# Out:
# Path to plot: /content/gdrive/My Drive/iss/prmls/colab/wks3_2_1_plot.png
